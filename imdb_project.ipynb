# %%
import pandas as pd
imdb = pd.read_csv("IMDB-database-update.csv",encoding='latin1')
imdb.head(10)
# Out:
#    movie_ID                                movie_title  duration  color  \
# 0         1                                     Avatar       178      1
# 1         2   Pirates of the Caribbean: At World's End       169      1
# 2         3                      The Dark Knight Rises       164      1
# 3         4                               Spider-Man 3       156      1
# 4         5         Batman v Superman: Dawn of Justice       183      1
# 5         6                           Superman Returns       169      1
# 6         7                               Man of Steel       143      1
# 7         8  The Hobbit: The Battle of the Five Armies       164      1
# 8         9                     The Amazing Spider-Man       153      1
# 9        10                                 Robin Hood       156      1
#
#    title_year      country language content_rating  budget_USD  gross_USD  \
# 0        2009          USA  English          PG-13   237000000  760505847
# ...

# %%
imdb.isnull().sum()
# Out:
# movie_ID                     0
# movie_title                  0
# duration                     0
# color                        0
# title_year                   0
# country                      0
# language                     0
# content_rating               0
# budget_USD                   0
# gross_USD                    0
# net_USD                      0
# profitable                   0
# director_name                0
# director_top20?              0
# director_facebook?           0
# director_facebook_likes      0
# actor_1_name                 0
# actor_top20?                 0
# actor_1_facebook?            0
# actor_1_facebook_likes       0
# actor_2_name                 0
# actor_top20?.1               0
# actor_2_facebook?            0
# actor_2_facebook_likes       0
# actor_3_name                 0
# actor_top20?.2               0
# actor_3_facebook?            0
# actor_3_facebook_likes       0
# cast_total_facebook_likes    0
# movie_facebook?              0
# ...

# %%
imdb[["duration","gross_USD"]].describe()
# Out:
#           duration     gross_USD
# count  3781.000000  3.781000e+03
# mean    109.950278  5.182002e+07
# std      22.299267  7.003776e+07
# min      37.000000  1.620000e+02
# 25%      95.000000  7.605668e+06
# 50%     106.000000  2.896520e+07
# 75%     120.000000  6.600997e+07
# max     325.000000  7.605058e+08

# %%
#imdb["color"].value_counts()
imdb["content_rating"].value_counts()
# Out:
# R            1715
# PG-13        1311
# PG            568
# G              88
# Not Rated      39
# Unrated        24
# Approved       14
# X              10
# NC-17           6
# Passed          3
# M               2
# GP              1
# Name: content_rating, dtype: int64

# %%
imdb[imdb.content_rating == 'PG-13'] #Menampilkan semua film dengan content rating PG-13
# Out:
#       movie_ID                                movie_title  duration  color  \
# 0            1                                     Avatar       178      1
# 1            2   Pirates of the Caribbean: At World's End       169      1
# 2            3                      The Dark Knight Rises       164      1
# 3            4                               Spider-Man 3       156      1
# 4            5         Batman v Superman: Dawn of Justice       183      1
# 5            6                           Superman Returns       169      1
# 6            7                               Man of Steel       143      1
# 7            8  The Hobbit: The Battle of the Five Armies       164      1
# 8            9                     The Amazing Spider-Man       153      1
# 9           10                                 Robin Hood       156      1
# 10          11                                  King Kong       201      1
# ...

# %%
imdb[imdb.title_year == 2013]
# Out:
#       movie_ID                                 movie_title  duration  color  \
# 6            7                                Man of Steel       143      1
# 18          19                         Monsters University       104      1
# 25          26                                 World War Z       123      1
# 26          27                     Star Trek Into Darkness       132      1
# 27          28                                 Pacific Rim       131      1
# 57          58                                      Frozen       102      1
# 86          87                                       Turbo        96      1
# 95          96                                 After Earth       100      1
# 109        110                                     Elysium       109      1
# 114        115                                    Oblivion       124      1
# 117        118                                     Gravity        91      1
# ...

# %%
total_row = len(imdb.axes[0])
total_column = len(imdb.axes[1])
print("Numbers of Rows :" +str(total_row))
print("Numbers of Columns :" +str(total_column)) #Mencari banyaknya baris dan kolom dari data IMDB-database-update
# Out:
# Numbers of Rows :3781
# Numbers of Columns :36

# %%
score = []
for i in imdb['imdb_score']:
    if i > 7.5:
        score.append('High')
    else:
        score.append('Low')

imdb['score_group'] = score

# %%
imdb['score_group']
# Out:
# 0       High
# 1        Low
# 2       High
# 3        Low
# 4        Low
# 5        Low
# 6        Low
# 7        Low
# 8        Low
# 9        Low
# 10       Low
# 11      High
# 12      High
# 13       Low
# 14       Low
# 15      High
# 16       Low
# 17       Low
# 18       Low
# 19       Low
# 20       Low
# 21       Low
# 22       Low
# 23       Low
# 24       Low
# 25       Low
# 26      High
# 27       Low
# 28       Low
# 29      High
#         ...
# 3751     Low
# 3752     Low
# 3753     Low
# 3754     Low
# 3755     Low
# 3756     Low
# 3757     Low
# 3758     Low
# 3759     Low
# 3760     Low
# 3761     Low
# 3762     Low
# 3763     Low
# 3764     Low
# 3765     Low
# 3766     Low
# 3767     Low
# 3768     Low
# 3769     Low
# 3770     Low
# 3771     Low
# 3772     Low
# 3773     Low
# 3774     Low
# 3775     Low
# 3776     Low
# 3777    High
# 3778     Low
# 3779     Low
# 3780    High
# Name: score_group, Length: 3781, dtype: object
